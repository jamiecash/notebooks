# %% [markdown]
# # Replicate ARKK Invest Fund
# 1) Get the holdings weightings
# 2) Get the account data from Alpaca
# 3) Calculate the target amount to invest and target number of shares in each constituent holding based on portfolio data
# 4) Calculate trades required to balance portfolio
# 5) Book the trades
# 6) Display orders to check what has been booked

# %% [markdown]
# ## Get the holding weighting for ARKK

# %%
import io
import pandas as pd
import requests


# Download CSV containg fund constituients and weightings from Ark
url=r"https://ark-funds.com/wp-content/uploads/funds-etf-csv/ARK_INNOVATION_ETF_ARKK_HOLDINGS.csv"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
response = requests.get(url, headers=headers)

# Load it into pandas
arkk_data = pd.read_csv(io.StringIO(response.content.decode('utf-8')))

# Remove any irrelevant rows, e.g. where fund is NaN or ticker is NaN. NaN fund is the fund risk statement, NaN ticker is not a stock
arkk_data = arkk_data[arkk_data['fund'].notna()]
arkk_data = arkk_data[arkk_data['ticker'].notna()]

# Convert weight to number, we will need to remove the %
arkk_data['weight'] = arkk_data['weight (%)'].str.slice(stop=-1).astype('float')

arkk_data.head()
# Out:
#          date  fund                       company ticker      cusip  \
# 0  04/13/2022  ARKK                     TESLA INC   TSLA  88160R101
# 1  04/13/2022  ARKK            TELADOC HEALTH INC   TDOC  87918A105
# 2  04/13/2022  ARKK                      ROKU INC   ROKU  77543R102
# 3  04/13/2022  ARKK   ZOOM VIDEO COMMUNICATIONS-A     ZM  98980L101
# 4  04/13/2022  ARKK  COINBASE GLOBAL INC -CLASS A   COIN  19260Q107
#
#        shares   market value ($) weight (%)  weight
# 0   1,085,944  $1,071,772,430.80      9.95%    9.95
# 1  10,789,238    $720,397,421.26      6.69%    6.69
# 2   6,179,485    $701,865,906.30      6.51%    6.51
# 3   6,341,311    $675,856,926.38      6.27%    6.27
# 4   4,234,706    $634,570,694.10      5.89%    5.89

# %% [markdown]
# ## Get the account data from Alpaca

# %% [markdown]
# ### Define a class to wrap the Alpaca API to provide data in dicts and dataframes, with type conversion

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import alpaca_trade_api as tradeapi

class Alpaca:
    """
    A wrapper around the Alpaca API to convert Alpaca native types to dicts and pandas DataFrames. Converts returned object to correct python data types
    """
    __api = None
    
    def __init__(self):
        """
        Connect to Alpaca using connection params contained in .alpaca_paper.vault
        """
        con_params = {}
        with open(".alpaca-paper.vault") as f:
            for line in f:
               (key, val) = line.split("=")
               con_params[key] = val.rstrip()

        # Connect
        self.__api = tradeapi.REST(con_params['key'], con_params['secret-key'], base_url=con_params['url'])
    

    @property
    def account_data(self) -> dict:
        """
        Returns the account data as a dict
        """
        
        account_obj = self.__api.get_account()

        # Get Account object vars as dict
        account_data = vars(account_obj)['_raw']

        # Convert items to correct data type
        for float_item in ['buying_power', 'regt_buying_power', 'daytrading_buying_power', 'non_marginable_buying_power', 'cash', 'accrued_fees', 'pending_transfer_in', 
                           'portfolio_value', 'multiplier', 'equity', 'last_equity', 'long_market_value', 'short_market_value', 'initial_margin', 'maintenance_margin', 
                           'last_maintenance_margin', 'sma']:
            account_data[float_item] = float(account_data[float_item])  

        for int_item in ['daytrade_count']:
            account_data[int_item] = int(account_data[int_item])

        for bool_item in ['pattern_day_trader', 'trading_blocked', 'transfers_blocked', 'account_blocked', 'trade_suspended_by_user', 'shorting_enabled']:
            account_data[bool_item] = bool(account_data[bool_item])

        for datetime_item in ['created_at']:
            account_data[datetime_item] = datetime.fromisoformat(account_data[datetime_item][0:-1])

        return account_data

    @property
    def positions(self) -> pd.DataFrame:
        """
        Returns the postions as a Pandas DataFrame
        """
        
        positions_list = self.__api.list_positions()
        columns = ['asset_class', 'asset_id', 'avg_entry_price', 'change_today', 'cost_basis', 'current_price', 'exchange', 'lastday_price', 'market_value', 
                   'qty', 'side', 'symbol', 'unrealized_intraday_pl', 'unrealized_intraday_plpc', 'unrealized_pl', 'unrealized_plpc']

        if len(positions_list) > 0:
            positions_data = pd.DataFrame([ position._raw for position in positions_list], columns=columns)
        else:
            positions_data = pd.DataFrame(columns=columns)
            
        # Replace None with NaN
        positions_data.fillna(inplace=True, value=np.NaN)

        # Convert items to correct data type
        positions_data = positions_data.astype({'qty': 'int32', 'avg_entry_price': 'float64', 'current_price': 'float64'})
        positions_data = positions_data.astype({'avg_entry_price': 'float64', 'change_today': 'float64', 'current_price': 'float64', 'lastday_price': 'float64',
                                                'market_value': 'float64', 'qty': 'int32', 'unrealized_intraday_pl': 'float64', 
                                                'unrealized_intraday_plpc': 'float64', 'unrealized_pl': 'float64', 'unrealized_plpc': 'float64'})

        return positions_data

    @property
    def orders(self) -> pd.DataFrame:
        """
        Returns the orders as a dataframe
        """
        
        orders_list = self.__api.list_orders(limit=500)
        columns = ['id', 'client_order_id', 'created_at', 'updated_at', 'submitted_at',
                   'filled_at', 'expired_at', 'canceled_at', 'failed_at', 'replaced_at',
                   'replaced_by', 'replaces', 'asset_id', 'symbol', 'asset_class',
                   'notional', 'qty', 'filled_qty', 'filled_avg_price', 'order_class',
                   'order_type', 'type', 'side', 'time_in_force', 'limit_price',
                   'stop_price', 'status', 'extended_hours', 'legs', 'trail_percent',
                   'trail_price', 'hwm']

        if len(orders_list) > 0:
            orders_data = pd.DataFrame([ order._raw for order in orders_list], columns=columns)
        else:
            orders_data = pd.DataFrame(columns=columns)
            
        # Replace None with NaN
        orders_data.fillna(inplace=True, value=np.NaN)

        # Convert items to correct data type
        orders_data = orders_data.astype({'qty': 'int32', 'filled_qty': 'int32', 'created_at': 'datetime64[ns]', 'filled_at': 'datetime64[ns]', 'updated_at': 'datetime64[ns]', 
                                          'submitted_at': 'datetime64[ns]', 'filled_at': 'datetime64[ns]', 'expired_at': 'datetime64[ns]', 'canceled_at': 'datetime64[ns]',
                                          'failed_at': 'datetime64[ns]', 'replaced_at': 'datetime64[ns]'})

        return orders_data
    
    def last_price(self, symbol: str) -> float:
        """
        Get the last price for the specified symbol
        """
        # TODO update times to now when aplaca subscription is upgraded
        bars = self.__api.get_bars(symbol, tradeapi.TimeFrame.Minute, pd.Timestamp('now').date() - timedelta(days=3), pd.Timestamp('now').date() - timedelta(days=2), 
                                   adjustment='raw', limit=1).df
        
        return bars['close'].values[0]
    
    def place_order(self, symbol: str, direction: str, qty: int):
        """
        Places an order. Nets against existing orders if unfilled.
        """
        # TODO cancel or edit orders first before booking new trades
        response = self.__api.submit_order(symbol=symbol, qty=qty, side=direction, type='market', time_in_force='gtc')
        
        print(f"{symbol} {qty} Response: {response}")
        

# Instance to use throughout notebook
al = Alpaca()

# %% [markdown]
# ### Test the output

# %%
al.account_data
# Out:
# {'id': 'c8b48627-6c21-48f5-92cd-1a6cdcc3c077',
#  'account_number': 'PA3LCDS5GZ05',
#  'status': 'ACTIVE',
#  'crypto_status': 'ACTIVE',
#  'currency': 'USD',
#  'buying_power': 111584.53,
#  'regt_buying_power': 111584.53,
#  'daytrading_buying_power': 0.0,
#  'non_marginable_buying_power': 0.0,
#  'cash': 8851.46,
#  'accrued_fees': 0.0,
#  'pending_transfer_in': 0.0,
#  'portfolio_value': 102733.07,
#  'pattern_day_trader': False,
#  'trading_blocked': False,
#  'transfers_blocked': False,
#  'account_blocked': False,
#  'created_at': datetime.datetime(2022, 3, 9, 14, 54, 49, 878543),
#  'trade_suspended_by_user': False,
#  'multiplier': 2.0,
#  'shorting_enabled': True,
#  'equity': 102733.07,
#  'last_equity': 102029.35,
#  'long_market_value': 93881.61,
#  'short_market_value': 0.0,
#  'initial_margin': 46940.805,
#  'maintenance_margin': 28164.483,
#  'last_maintenance_margin': 27953.37,
#  'sma': 100269.08,
#  'daytrade_count': 0}

# %%
al.positions[['symbol','side', 'qty', 'avg_entry_price', 'current_price']].head()
# Out:
#   symbol  side  qty  avg_entry_price  current_price
# 0     ZM  long   56       108.432679         107.42
# 1   VCYT  long   44        25.580682          25.80
# 2      U  long   50        89.150000          90.82
# 3    TXG  long   21        71.460000          72.34
# 4   TWST  long   26        45.490000          44.86

# %%
al.orders[['symbol','side', 'qty', 'filled_qty']].head()
# Out:
# Empty DataFrame
# Columns: [symbol, side, qty, filled_qty]
# Index: []

# %%
"""
Add positions and unfilled orders to dataframe
"""

# Get unfilled orders. Calculate unfilled quantity, and sign based on trade direction. Group by symbol.
orders = al.orders
unfilled_orders = orders[orders['filled_qty'] < orders['qty']]
if len(unfilled_orders.index) > 0:
    unfilled_orders['unfilled_qty'] = unfilled_orders.apply(lambda row: row['qty'] - row['filled_qty'] if row['side'] == 'buy' else (row['qty'] - row['filled_qty']) * -1, axis=1)
else:
    unfilled_orders['unfilled_qty'] = 0
    
unfilled_orders = unfilled_orders[['symbol', 'unfilled_qty']]
unfilled_orders = unfilled_orders.groupby(['symbol']).sum().reset_index()

# Get positions, rename columns ready for merge
positions = al.positions
positions.rename({'qty': 'position_qty', 'side': 'position_side'}, axis='columns', inplace=True)

# Rename arc data ticker column to symbol ready for merge
arkk_data.rename({'ticker': 'symbol'}, axis='columns', inplace=True)

# Merge the data frames
data = pd.merge(arkk_data, unfilled_orders, how='left', on='symbol')
data = pd.merge(data, positions, how='left', on='symbol')

# position_qty and unfilled_qty should be 0 if NaN
data['position_qty'] = data['position_qty'].fillna(0)
data['unfilled_qty'] = data['unfilled_qty'].fillna(0)

# Remove unneeded columns
data = data[['symbol', 'company', 'weight', 'position_qty', 'unfilled_qty']]

data.head()
# Out:
#   symbol                       company  weight  position_qty  unfilled_qty
# 0   TSLA                     TESLA INC    9.95             9           0.0
# 1   TDOC            TELADOC HEALTH INC    6.69            93           0.0
# 2   ROKU                      ROKU INC    6.51            55           0.0
# 3     ZM   ZOOM VIDEO COMMUNICATIONS-A    6.27            56           0.0
# 4   COIN  COINBASE GLOBAL INC -CLASS A    5.89            37           0.0

# %% [markdown]
# ## Calculate the target amount to invest and target number of shares in each constituent holding based on portfolio data

# %%
# Target investment amount to maintain weighting
data['target_invest_amt'] = Alpaca().account_data['portfolio_value'] / 100 * data['weight']

# Add target number of shares to get close to target investment amount, using last price
for symbol in data['symbol']:
    # Update df
    data.loc[data['symbol']==symbol, 'last_price'] = al.last_price(symbol)

    # Calculate target number of shares Max number of shares that can be purchased with target_invest_amt
    data['target_shares'] = (data['target_invest_amt'] / data['last_price']).apply(np.floor)

data = data.astype({'target_shares': 'int32'})
data.head()
# Out:
#   symbol                       company  weight  position_qty  unfilled_qty  \
# 0   TSLA                     TESLA INC    9.95             9           0.0
# 1   TDOC            TELADOC HEALTH INC    6.69            93           0.0
# 2   ROKU                      ROKU INC    6.51            55           0.0
# 3     ZM   ZOOM VIDEO COMMUNICATIONS-A    6.27            56           0.0
# 4   COIN  COINBASE GLOBAL INC -CLASS A    5.89            37           0.0
#
#    target_invest_amt  last_price  target_shares
# 0       10217.374410     1006.95             10
# 1        6869.772342       65.00            105
# 2        6684.935418      113.00             59
# 3        6438.486186      110.10             58
# 4        6048.274902      159.91             37

# %% [markdown]
# ## Calculate trades required to balance portfolio

# %%
# How many shares to we need to rebalance
data['rebalance_qty'] = (data['target_shares'] - data['position_qty'] - data['unfilled_qty'])

# Get the trades. Where rebalance qty != 0
trades = data[data['rebalance_qty'] != 0]

# Remove unnecessary columns
trades = trades[['symbol', 'company', 'target_invest_amt', 'last_price', 'target_shares', 'position_qty', 'unfilled_qty', 'rebalance_qty']]

trades
# Out:
#    symbol                       company  target_invest_amt  last_price  \
# 0    TSLA                     TESLA INC       10217.374410    1006.950
# 1    TDOC            TELADOC HEALTH INC        6869.772342      65.000
# 2    ROKU                      ROKU INC        6684.935418     113.000
# 3      ZM   ZOOM VIDEO COMMUNICATIONS-A        6438.486186     110.100
# 5      SQ                     BLOCK INC        5904.512850     120.420
# 6    EXAS           EXACT SCIENCES CORP        5391.076950      67.440
# 7       U            UNITY SOFTWARE INC        5000.865666      90.650
# 8    TWLO                TWILIO INC - A        4271.786688     145.650
# 9    SPOT         SPOTIFY TECHNOLOGY SA        4199.905662     142.010
# 10   CRSP        CRISPR THERAPEUTICS AG        3778.888224      60.990
# 11   PATH          UIPATH INC - CLASS A        3460.557966      19.870
# 12   NTLA     INTELLIA THERAPEUTICS INC        3388.676940      62.300
# 13   BEAM         BEAM THERAPEUTICS INC        2875.241040      51.100
# 15   DKNG         DRAFTKINGS INC - CL A        2289.924114      16.440
# 16     PD                 PAGERDUTY INC        2259.117960      30.670
# 17   FATE         FATE THERAPEUTICS INC        2187.236934      37.050
# 18   HOOD     ROBINHOOD MARKETS INC - A        1992.131292      11.240
# 19   SGFY   SIGNIFY HEALTH INC -CLASS A        1817.563086      16.450
# 20   RBLX          ROBLOX CORP -CLASS A        1653.263598      43.880
# 21    TXG      10X GENOMICS INC-CLASS A        1653.263598      71.510
# 22   TWST         TWIST BIOSCIENCE CORP        1293.858468      45.500
# 23    DNA  GINKGO BIOWORKS HOLDINGS INC        1293.858468       3.630
# 24   VCYT                  VERACYTE INC        1211.708724      25.010
# 26   NVTA                  INVITAE CORP        1160.365134       7.100
# 27   SSYS                 STRATASYS LTD        1006.334364      21.690
# 28   PACB  PACIFIC BIOSCIENCES OF CALIF         965.259492       8.460
# 29    TSP     TUSIMPLE HOLDINGS INC - A         872.841030      10.555
# 30   TWOU                        2U INC         708.541542      12.010
# 31   MTLS            MATERIALISE NV-ADR         688.004106      18.220
# 32   CERS                    CERUS CORP         492.898464       5.190
# 33    BLI           BERKELEY LIGHTS INC         277.255386       6.050
# 34   CGEN                  COMPUGEN LTD         154.030770       2.900
#
#     target_shares  position_qty  unfilled_qty  rebalance_qty
# 0              10             9           0.0            1.0
# 1             105            93           0.0           12.0
# 2              59            55           0.0            4.0
# 3              58            56           0.0            2.0
# 5              49            44           0.0            5.0
# 6              79            75           0.0            4.0
# 7              55            50           0.0            5.0
# 8              29            27           0.0            2.0
# 9              29            28           0.0            1.0
# 10             61            53           0.0            8.0
# 11            174           157           0.0           17.0
# 12             54            50           0.0            4.0
# 13             56            53           0.0            3.0
# 15            139           121           0.0           18.0
# 16             73            64           0.0            9.0
# 17             59            54           0.0            5.0
# 18            177           155           0.0           22.0
# 19            110           104           0.0            6.0
# 20             37            35           0.0            2.0
# 21             23            21           0.0            2.0
# 22             28            26           0.0            2.0
# 23            356           368           0.0          -12.0
# 24             48            44           0.0            4.0
# 26            163           142           0.0           21.0
# 27             46            42           0.0            4.0
# 28            114           111           0.0            3.0
# 29             82            73           0.0            9.0
# 30             58            50           0.0            8.0
# 31             37            34           0.0            3.0
# 32             94            92           0.0            2.0
# 33             45            41           0.0            4.0
# 34             53            52           0.0            1.0

# %% [markdown]
# ## Book the trades

# %%
# Iterate rows, get rebalance_qty and book trades
for rownum, rowdata in trades.iterrows():
    # Number of shares for symbol
    symbol = rowdata['symbol']
    shares = rowdata['rebalance_qty']
    
    # Book the trade
    if shares != 0:
        al.place_order(symbol=symbol, qty=abs(shares), direction='buy' if shares > 0 else 'sell')
# Out:
# TSLA 1.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#     'canceled_at': None,
#     'client_order_id': '5ef9687c-0d83-41c9-b286-6dd3790afa5a',
#     'created_at': '2022-04-13T11:35:03.921659837Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'a319bd0e-22bc-4f5f-948b-640978fd4797',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:03.917705597Z',
#     'symbol': 'TSLA',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:03.921659837Z'})
# TDOC 12.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'd2eb2ae7-fb5e-47d8-a0bf-ff77f0f47f94',
#     'canceled_at': None,
#     'client_order_id': 'c6b5b29d-1de6-4ad7-a17c-f0627fd60381',
#     'created_at': '2022-04-13T11:35:04.028343995Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '98cd7286-0246-4d60-bc43-dc3473bbe276',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '12',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:04.024912365Z',
#     'symbol': 'TDOC',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:04.028343995Z'})
# ROKU 4.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'c527d9ac-b902-4dca-89c1-b6735e7460de',
#     'canceled_at': None,
#     'client_order_id': 'ab476973-4279-42ce-8c8a-3cc24e7047d2',
#     'created_at': '2022-04-13T11:35:04.132753784Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '412d9a9d-f578-4164-96a5-d3d5c48f1948',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '4',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:04.129463174Z',
#     'symbol': 'ROKU',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:04.132753784Z'})
# ZM 2.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'c2963936-2b0f-4eae-a0cc-dc28d3b33885',
#     'canceled_at': None,
#     'client_order_id': '3431ab91-e1e9-40ed-96fa-1a0522f29d33',
#     'created_at': '2022-04-13T11:35:04.237657042Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'add2d717-b1d7-4ea2-881b-a92580ab0545',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '2',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:04.233832623Z',
#     'symbol': 'ZM',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:04.237657042Z'})
# SQ 5.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '3bd2f8c7-ceb9-4916-8a1e-4bcf3654efd9',
#     'canceled_at': None,
#     'client_order_id': '092e4aae-0f09-4a63-bc1f-976646f4b9d8',
#     'created_at': '2022-04-13T11:35:04.342299071Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'f4f39e39-a466-4459-b034-720ea0034288',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '5',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:04.337989031Z',
#     'symbol': 'SQ',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:04.342299071Z'})
# EXAS 4.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '52f26058-2c7b-48ea-bf35-debdffce1496',
#     'canceled_at': None,
#     'client_order_id': '9232d63b-6477-48f5-a17c-3957884d495b',
#     'created_at': '2022-04-13T11:35:04.44585425Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '2bd60036-94f8-4e2e-ada4-880edcecfade',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '4',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:04.44118988Z',
#     'symbol': 'EXAS',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:04.44585425Z'})
# U 5.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '914dfaf2-1ddc-4b87-9695-8001a7beed9e',
#     'canceled_at': None,
#     'client_order_id': '228f3df8-8cf1-43d6-83e2-b19a4fed960e',
#     'created_at': '2022-04-13T11:35:04.551716268Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'd3b836a3-84a3-4f8e-bcf6-c2c782f3fe91',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '5',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:04.547023999Z',
#     'symbol': 'U',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:04.551716268Z'})
# TWLO 2.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '4831318c-901a-4b29-b508-28ca8ccb2518',
#     'canceled_at': None,
#     'client_order_id': '0890cd66-dce1-4bcb-b342-51b202f3dde3',
#     'created_at': '2022-04-13T11:35:04.659092086Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '103dc30c-ef0c-4c67-a80c-ef875ad1221a',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '2',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:04.654488007Z',
#     'symbol': 'TWLO',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:04.659092086Z'})
# SPOT 1.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '39a26dc1-927a-4590-b103-b8068a013e7f',
#     'canceled_at': None,
#     'client_order_id': '2a2e6a34-55b1-421a-a211-e933798573ae',
#     'created_at': '2022-04-13T11:35:04.761870395Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '3c3de662-25ab-41ed-a6b2-cbd3a6b735ab',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:04.757464655Z',
#     'symbol': 'SPOT',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:04.761870395Z'})
# CRSP 8.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '6462fdfd-6105-4dee-839a-2d4c88dbee56',
#     'canceled_at': None,
#     'client_order_id': '799d7e4e-2ae8-49bf-983f-c1230b8273c3',
#     'created_at': '2022-04-13T11:35:04.869681373Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '12c96418-5eea-46d1-942e-930109298d1a',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '8',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:04.864718804Z',
#     'symbol': 'CRSP',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:04.869681373Z'})
# PATH 17.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'b839dd23-cd51-4d0f-8352-7a14b517391c',
#     'canceled_at': None,
#     'client_order_id': 'c429702a-bdf2-425b-b7b5-2451c11f131f',
#     'created_at': '2022-04-13T11:35:04.974155142Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '1dbab754-dc59-455f-9273-a539626037b4',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '17',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:04.969543942Z',
#     'symbol': 'PATH',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:04.974155142Z'})
# NTLA 4.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '961e4631-0f65-4c2b-ae87-8a5f20b847be',
#     'canceled_at': None,
#     'client_order_id': '732452ab-5411-419e-9d09-09d187e42b7e',
#     'created_at': '2022-04-13T11:35:05.07878798Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'd31d129f-d568-476e-86da-f89f711677d5',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '4',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:05.076050581Z',
#     'symbol': 'NTLA',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:05.07878798Z'})
# BEAM 3.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'bf6c1e55-a7ef-4701-9e30-3c43db26b103',
#     'canceled_at': None,
#     'client_order_id': '187174d8-f74e-4a83-8ca3-2e2da671b4ef',
#     'created_at': '2022-04-13T11:35:05.186459829Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '5a1e7a15-9dcc-4b12-8289-09f97534deee',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '3',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:05.178997119Z',
#     'symbol': 'BEAM',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:05.186459829Z'})
# DKNG 18.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '86c838da-0e38-4d71-b56d-7794cf599f1e',
#     'canceled_at': None,
#     'client_order_id': 'c34086fd-3566-4ede-8cc9-55fa5c5c269d',
#     'created_at': '2022-04-13T11:35:05.293486767Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '3aa47d67-4c51-46eb-ad27-df27c8d1dd1f',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '18',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:05.288208517Z',
#     'symbol': 'DKNG',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:05.293486767Z'})
# PD 9.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'b86009cf-b589-42f6-90e7-9519217d58f4',
#     'canceled_at': None,
#     'client_order_id': 'd0e61cb5-d630-4113-83ad-485bc42f24ee',
#     'created_at': '2022-04-13T11:35:05.401281155Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'a81ef684-3440-4fa9-aa15-6bcae383d2d9',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '9',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:05.396819275Z',
#     'symbol': 'PD',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:05.401281155Z'})
# FATE 5.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '29e35278-c259-40ee-bd30-79192459b691',
#     'canceled_at': None,
#     'client_order_id': '432f636c-a153-4561-9a29-3ee8185fa366',
#     'created_at': '2022-04-13T11:35:05.503465124Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '2ed524fe-3c58-4a2d-a4c2-6e6866a36121',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '5',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:05.500788514Z',
#     'symbol': 'FATE',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:05.503465124Z'})
# HOOD 22.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'c6e72c57-a1a9-4e4b-a7d0-029160f8bd64',
#     'canceled_at': None,
#     'client_order_id': '98e605b7-22dc-42d6-b8a7-a9507407f232',
#     'created_at': '2022-04-13T11:35:05.610034432Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'fba1c527-b3f5-40ce-871d-d3505a43f327',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '22',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:05.605221283Z',
#     'symbol': 'HOOD',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:05.610034432Z'})
# SGFY 6.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'f4955e70-ba15-4823-aa6c-3d85b642eb5a',
#     'canceled_at': None,
#     'client_order_id': '5ef006ed-9b4e-4f7b-aa1e-7aa92c5e8562',
#     'created_at': '2022-04-13T11:35:05.715773131Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '16990e15-f527-484c-b3fa-6dfae6e3bc64',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '6',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:05.710622201Z',
#     'symbol': 'SGFY',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:05.715773131Z'})
# RBLX 2.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '550823f6-8d6f-4a45-91e3-d55ea3f98bb7',
#     'canceled_at': None,
#     'client_order_id': '8fc26cad-57df-434b-87d6-77f9ec87cda1',
#     'created_at': '2022-04-13T11:35:05.818620639Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'dc6ef1e4-ce59-473a-983f-de837055f0c5',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '2',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:05.815461849Z',
#     'symbol': 'RBLX',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:05.818620639Z'})
# TXG 2.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '10fdd677-ec53-4f7e-b719-713b7917a8ff',
#     'canceled_at': None,
#     'client_order_id': '2ea3c7be-7e69-45f9-b929-e8d2f6bc7d50',
#     'created_at': '2022-04-13T11:35:05.926330447Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'd9946b6c-e9fb-4fdc-8b40-ecdb6404ee11',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '2',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:05.920666038Z',
#     'symbol': 'TXG',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:05.926330447Z'})
# TWST 2.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '8e4ee6e8-4031-44af-a923-ff871868a45c',
#     'canceled_at': None,
#     'client_order_id': '9bf2f8b4-b818-4c0d-be16-125f988ec90f',
#     'created_at': '2022-04-13T11:35:06.031728426Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '8f5b8e97-d721-420d-a1ca-118a06403e62',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '2',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:06.026634126Z',
#     'symbol': 'TWST',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:06.031728426Z'})
# DNA 12.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '199d7213-40d8-45c2-a608-37c3a1a5b14a',
#     'canceled_at': None,
#     'client_order_id': '14b70e6e-f381-4998-86f9-e52ecfb55660',
#     'created_at': '2022-04-13T11:35:06.133634044Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'e940c0e2-f241-4358-a38c-e682650661e1',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '12',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'sell',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:06.132960474Z',
#     'symbol': 'DNA',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:06.133634044Z'})
# VCYT 4.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'e281541b-3e3b-4023-bc3b-57f93090fdd5',
#     'canceled_at': None,
#     'client_order_id': '64d11d3c-1cbc-48e1-b7b8-99083ed4c080',
#     'created_at': '2022-04-13T11:35:06.239505123Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '47a7c7c8-154f-447f-a21d-e41e04279c90',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '4',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:06.234687253Z',
#     'symbol': 'VCYT',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:06.239505123Z'})
# NVTA 21.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '9144c3a2-0712-4a46-a0d6-1848e02996ee',
#     'canceled_at': None,
#     'client_order_id': 'a6419259-bbe3-4ef7-bee7-f4502be1a2cb',
#     'created_at': '2022-04-13T11:35:06.347110581Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '9fc758a9-fd89-4f09-bf2e-9287e6018fee',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '21',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:06.342065022Z',
#     'symbol': 'NVTA',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:06.347110581Z'})
# SSYS 4.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '9c549061-23f4-478e-91c8-b1cb53899775',
#     'canceled_at': None,
#     'client_order_id': '15f79da3-0693-4191-8292-b94d666b7ca0',
#     'created_at': '2022-04-13T11:35:06.453335659Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'cac9770e-823f-4a6b-8256-1eb4b948db4b',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '4',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:06.44887835Z',
#     'symbol': 'SSYS',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:06.453335659Z'})
# PACB 3.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'cdf92f8c-cd8c-4843-a904-1feb22ae7794',
#     'canceled_at': None,
#     'client_order_id': '6dc2bb7f-aa0c-44b8-a81e-ddb5d59ba93a',
#     'created_at': '2022-04-13T11:35:06.559348338Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '49854ac5-3fde-4da3-905e-ffb75006f3f1',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '3',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:06.554797398Z',
#     'symbol': 'PACB',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:06.559348338Z'})
# TSP 9.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '9a2465cd-a993-4519-abc8-8b5d1a212306',
#     'canceled_at': None,
#     'client_order_id': '392102a0-24a6-416a-b6aa-6c2a9b62e41d',
#     'created_at': '2022-04-13T11:35:06.663131626Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '3b3b9eb9-5399-4301-8273-d61e038a7808',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '9',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:06.658309857Z',
#     'symbol': 'TSP',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:06.663131626Z'})
# TWOU 8.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'c4e600f3-6406-4325-bc7c-a2e2eba32963',
#     'canceled_at': None,
#     'client_order_id': '483511a3-b035-4e84-a2fe-e981c3cdfab6',
#     'created_at': '2022-04-13T11:35:06.780952603Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'c821815f-2367-4943-b256-f28882fd7a1b',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '8',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:06.775809964Z',
#     'symbol': 'TWOU',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:06.780952603Z'})
# MTLS 3.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '00aa58d7-55a9-4a39-9045-c7415d8d1a06',
#     'canceled_at': None,
#     'client_order_id': 'cdb7ad49-b89a-4c38-a556-eb9c659655ce',
#     'created_at': '2022-04-13T11:35:06.885435422Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'deb97fe8-6ed5-4945-b54a-f223f4ca74ca',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '3',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:06.880799872Z',
#     'symbol': 'MTLS',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:06.885435422Z'})
# CERS 2.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '4898da21-55f0-4bc9-aee1-f91387792545',
#     'canceled_at': None,
#     'client_order_id': '66b377ca-16f1-43a3-af24-ab152d335bc1',
#     'created_at': '2022-04-13T11:35:06.988750621Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'c7243dc2-ffcf-4974-9930-a0640f08f031',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '2',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:06.985649561Z',
#     'symbol': 'CERS',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:06.988750621Z'})
# BLI 4.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': '02e634c9-69d4-4aab-a7ca-6dca06c16396',
#     'canceled_at': None,
#     'client_order_id': '9af0e6a3-25fe-441c-8a5e-ac929674e4b0',
#     'created_at': '2022-04-13T11:35:07.094075229Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '31fdf2db-3a5f-4246-af76-803438490bd2',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '4',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:07.08909157Z',
#     'symbol': 'BLI',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:07.094075229Z'})
# CGEN 1.0 Response: Order({   'asset_class': 'us_equity',
#     'asset_id': 'c3f2ab3d-6ca7-4d44-944f-98c9bf54402b',
#     'canceled_at': None,
#     'client_order_id': '4e45ffb2-42a1-4d39-9087-dbef811199a4',
#     'created_at': '2022-04-13T11:35:07.201219818Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '1f7f2126-eec0-4684-be8b-c2b1b6f22813',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-04-13T11:35:07.196635438Z',
#     'symbol': 'CGEN',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-04-13T11:35:07.201219818Z'})

# %% [markdown]
# ## Display the orders to check what has been booked

# %%
al.orders[['symbol','side', 'qty']]
# Out:
#    symbol  side  qty
# 0    CGEN   buy    1
# 1     BLI   buy    4
# 2    CERS   buy    2
# 3    MTLS   buy    3
# 4    TWOU   buy    8
# 5     TSP   buy    9
# 6    PACB   buy    3
# 7    SSYS   buy    4
# 8    NVTA   buy   21
# 9    VCYT   buy    4
# 10    DNA  sell   12
# 11   TWST   buy    2
# 12    TXG   buy    2
# 13   RBLX   buy    2
# 14   SGFY   buy    6
# 15   HOOD   buy   22
# 16   FATE   buy    5
# 17     PD   buy    9
# 18   DKNG   buy   18
# 19   BEAM   buy    3
# 20   NTLA   buy    4
# 21   PATH   buy   17
# 22   CRSP   buy    8
# 23   SPOT   buy    1
# 24   TWLO   buy    2
# 25      U   buy    5
# 26   EXAS   buy    4
# 27     SQ   buy    5
# 28     ZM   buy    2
# 29   ROKU   buy    4
# 30   TDOC   buy   12
# 31   TSLA   buy    1
